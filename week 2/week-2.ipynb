# %%
11
# Out:
# 11

# %%
2.14
# Out:
# 2.14

# %%
#print("Hello, gais gais Python 2 ")
#print("Hello, gais gais Python 1 ")

"Hello, Python 2"
#"Hello,  gais gais Python 1"
# Out:
# 'Hello, Python 2'

# %%
type(12)
# Out:
# int

# %%
type(2.14)
# Out:
# float

# %%
type("Hello, gais gais Phyton 1")
# Out:
# str

# %%
type(12.0)
# Out:
# float

# %%
type(-1)
# Out:
# int

# %%
type (-6)
# Out:
# int

# %%
type(4)
# Out:
# int

# %%
type(0)
# Out:
# int

# %%
type(1.0) # Notice that 1 is an int, and 1.0 is a float
# Out:
# float

# %%
type(0.5)
# Out:
# float

# %%
type(0.56)
# Out:
# float

# %%
import sys
sys.float_info
# Out:
# sys.float_info(max=1.7976931348623157e+308, max_exp=1024, max_10_exp=308, min=2.2250738585072014e-308, min_exp=-1021, min_10_exp=-307, dig=15, mant_dig=53, epsilon=2.220446049250313e-16, radix=2, rounds=1)

# %%
type(2)
# Out:
# int

# %%
float(2)
# Out:
# 2.0

# %%
type(float(2))
# Out:
# float

# %%
int(1.1)
# Out:
# 1

# %%
int('1')
# Out:
# 1

# %%
int('1 or 2 people')
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-22-cd59a23aeda5> in <cell line: 1>()
# ----> 1 int('1 or 2 people')
#
# ValueError: invalid literal for int() with base 10: '1 or 2 people'

# %%
float('1.2')
# Out:
# 1.2

# %%
str(1)
# Out:
# '1'

# %%
str(1.2)
# Out:
# '1.2'

# %%
True
# Out:
# True

# %%
False
# Out:
# False

# %%
type(True)
# Out:
# bool

# %%
type(False)
# Out:
# bool

# %%
int(True)
# Out:
# 1

# %%
bool(1)
# Out:
# True

# %%
bool(0)
# Out:
# False

# %%
float(True)
# Out:
# 1.0

# %%
type(6/2)
# Out:
# float

# %%
type(6//2)
# Out:
# int

# %%
type(10.55+10.5-5)
# Out:
# float

# %%
type(50 - 60)
# Out:
# int

# %%
 5* 5
# Out:
# 25

# %%
25/5
# Out:
# 5.0

# %%
25/6
# Out:
# 4.166666666666667

# %%
25 // 5
# Out:
# 5

# %%
25 // 6
# Out:
# 4

# %%
160/60
# Out:
# 2.6666666666666665

# %%
30 + 2 * 60 // 10
# Out:
# 42

# %%
(30 + 2) * 60
# Out:
# 1920

# %%
x = 43 + 60 + 16 + 41
x
# Out:
# 160

# %%
y = x / 60
y
# Out:
# 2.6666666666666665

# %%
x = x / 60
print(x)
# Out:
# 2.6666666666666665

# %%
x
# Out:
# 2.6666666666666665

# %%
total_min = 43 + 42 + 57
total_min
# Out:
# 142

# %%
float (total_min)
# Out:
# 142.0

# %%
a=2
a
# Out:
# 2

# %%
print(float(a))
# Out:
# 2.0

# %%
total_hours = total_min / 60
total_hours
# Out:
# 2.3666666666666667

# %%
total_hours = (43 + 42 + 57) / 60
total_hours
# Out:
# 2.3666666666666667

# %%
x = 3 + 2 * 2
x
# Out:
# 7

# %%
y = (3 + 2) * 2
y
# Out:
# 10

# %%
z = x + y
z
# Out:
# 17

# %%
panjang = 20.5
lebar = 25
tinggi = 10

keliling = 2 * (panjang + lebar)
luas = panjang * lebar
volume = panjang * lebar * tinggi

print("Panjang = " , panjang)
print("Lebar = " , lebar)
print("Tinggi = " , tinggi)
print("Keliling = " , keliling)
print("Volume = " , volume)
# Out:
# Panjang =  20.5
# Lebar =  25
# Tinggi =  10
# Keliling =  91.0
# Volume =  5125.0

# %%
Nilairataratashafira = ((75 + 85)/2)
print(Nilairataratashafira)
# Out:
# 80.0

# %%
jumlahnilaihanif = (75 + 90)
jumlahnilaiandi = (70 + 75)
total = (jumlahnilaihanif)+(jumlahnilaiandi)
print(jumlahnilaihanif)
print(jumlahnilaiandi)
print(total)
# Out:
# 165
# 145
# 310

# %%
NilairatarataWidya = ((85 + 85)/2)
NilairatarataDhanar = ((85 + 85)/2)
NilairatarataHikma = ((80 + 75)/2)
NilairatarataNedia = ((95 + 80)/2)
print(NilairatarataWidya)
print(NilairatarataDhanar)
print(NilairatarataHikma)
print(NilairatarataNedia)
# Out:
# 85.0
# 85.0
# 77.5
# 87.5

# %%
DataKalkulus1 = (85,80,75,95,85,75,70,85,80)
RataRata = sum(DataKalkulus1)/len(DataKalkulus1 )
print(RataRata)
# Out:
# 81.11111111111111

# %%
DataMetodeStatistika = (75,90,80,80,85,90,75,85,75)
RataRata = sum(DataMetodeStatistika )/len(DataMetodeStatistika )
print(RataRata)
# Out:
# 81.66666666666667

# %%
gaji_per_jam = 30000
hari_kerja = 27
jam_kerja_per_hari = 8
total_jam_kerja = jam_kerja_per_hari * hari_kerja
gaji_awal = total_jam_kerja*gaji_per_jam
hari_tidak_masuk = 3
jam_kerja_hilang = hari_tidak_masuk * jam_keja_per_hari
gaji_setelah_potongan = gaji_awal - (jam_kerja_hilang*gaji_per_jam)
tunjangan = 0.10 * gaji_setelah_potongan
lembur_jam = 5
upah_lembur_per_jam = 10000
gaji_lembur = lembur_jam * upah_lembur_per_jam
gaji_total = gaji_setelah_potongan + tunjangan + gaji_lembur

print("Gaji setelah potongan : Rp",gaji_setelah_potongan)
print("Tunjangan: Rp", tunjangan)
print("Gaji total setelah tunjangan dan lembur", gaji_total)
# Out:
# Gaji setelah potongan : Rp 5760000
# Tunjangan: Rp 576000.0
# Gaji total setelah tunjangan dan lembur 6386000.0
