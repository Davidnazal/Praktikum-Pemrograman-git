# %%
print ("Selamat datang di Toko Maju Jaya")
print ("Senin, 4 September 2023, Pukul 13.05")
print(" ")

print ("DAFTAR BELANJA:")

item1 = "Sabun"
item2 = "Shampo"
item3 = "Mie instant"
item4 = "Detergen"
harga1 = 10000
harga2 = 15000
harga3 = 5000
harga4 = 17500

total = harga1 + harga2 + harga3 + harga4

print(f"{item1} = Rp {harga1}")
print(f"{item2} = Rp {harga2}")
print(f"{item3} = Rp {harga3}")
print(f"{item4} = Rp {harga4}")

print(" ")
print(f"Total = Rp {total}")

with open('Kuitansi.txt', 'w') as file:
        file.write("Selamat Datang di Toko Maju Jaya\n")
        file.write("\n")
        file.write("Kuitansi - 4 Septermber 2023, Pukul: 13.05\n")
        file.write(" \n")
        file.write("{item1} = Rp {harga1}\n")
        file.write("{item2} = Rp {harga2}\n")
        file.write("{item3} = Rp {harga3}\n")
        file.write("{item4} = Rp {harga4}\n")
        file.write("\n")
        file.write(f"fTotal Belanja = Rp {total}\n")
# Out:
# Selamat datang di Toko Maju Jaya
# Senin, 4 September 2023, Pukul 13.05
#
# DAFTAR BELANJA:
# Sabun = Rp 10000
# Shampo = Rp 15000
# Mie instant = Rp 5000
# Detergen = Rp 17500
#
# Total = Rp 47500
