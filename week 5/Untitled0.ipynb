# %%
#Weekly Exercise 1
tahun = int(input("Masukan tahun: "))
if (tahun % 4 == 0 and tahun % 100 != 0) or (tahun % 400 == 0):
    print(f"{tahun} adalah tahun kabisat.")
else:
    print(f"{tahun} bukan tahun kabisat.")
# Out:
# Masukan tahun: 2012
# 2012 adalah tahun kabisat.

# %%
tahun = int(input("Masukan tahun: "))
if (tahun % 4 == 0 and tahun % 100 != 0) or (tahun % 400 == 0):
    print(f"{tahun} adalah tahun kabisat.")
else:
    print(f"{tahun} bukan tahun kabisat.")
# Out:
# Masukan tahun: 2013
# 2013 bukan tahun kabisat.

# %%
#Weekly Exercise 2
angka_1 = int(input("Masukkan angka: "))
angka_2 = int(input("Masukkan angka: "))
angka_3 = int(input("Masukkan angka: "))
if angka_1 > angka_2 and angka_1 > angka_3:
    print(f"{angka_1} adalah angka terbesar.")
elif angka_2 > angka_1 and angka_2 > angka_3:
    print(f"{angka_2} adalah angka terbesar.")
else:
    print(f"{angka_3} adalah angka terbesar.")
# Out:
# Masukkan angka: 2
# Masukkan angka: 6
# Masukkan angka: 1
# 6 adalah angka terbesar.

# %%
#Weekly Exercise 3
status = input("Status: (member/tidak): ") == "member"
total = int(input("Masukkan total belanja: "))
diskon = 0
if total > 200000:
  diskon = 4
elif total > 100000:
  diskon = 3
if status == "member":
  diskon += 2

total_diskon = total * (diskon / 100)
total_bayar = total - total_diskon
print(f"Total diskon: {total_diskon}")
print(f"Total yang harus dibayar: {total_bayar}")
# Out:
# Status: (member/tidak): member
# Masukkan total belanja: 250000
# Total diskon: 10000.0
# Total yang harus dibayar: 240000.0

# %%
#Weekly Exercise 4
Username = input("Masukkan Username: ")
Email = input("Masukkan Email: ")
Password = input("Masukkan Password: ")

if not Username:
  print ("Invalid, Username tidak boleh kosong")
elif not "@" in Email:
  print ("Invalid, Email tidak valid, gunakan @ pada email")
elif len(Password) < 8:
  print ("Invalid, Password harus lebih dari 8 karakter")
else:
  print ("Akun berhasil bibuat")
# Out:
# Masukkan Username: david
# Masukkan Email: david@gmail.com
# Masukkan Password: 123456789
# Akun berhasil bibuat
