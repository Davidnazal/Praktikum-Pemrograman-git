# %%
print('Hello, gais gais phyton')
# Out:
# Hello, gais gais phyton

# %%
print("Universitas Tidar")
# Out:
# Universitas Tidar

# %%
import sys
print(sys.version)
# Out:
# 3.10.12 (main, Jul 29 2024, 16:56:48) [GCC 11.4.0]

# %%
print('Hello gais gais Phyton') # Baris ini print sebagai string
print('Hi') # untuk print Hi
# Out:
# Hello gais gais Phyton
# Hi

# %%
frint("Hello gais gais Phyton")
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-11-fd4d246b62f9> in <cell line: 1>()
# ----> 1 frint("Hello gais gais Phyton")
#
# NameError: name 'frint' is not defined

# %%
print("Hello gais gais Phyton)
# Out:
#   File "<ipython-input-12-e2098e7302f5>", line 1
#     print("Hello gais gais Phyton)
#           ^
# SyntaxError: unterminated string literal (detected at line 1)

# %%
print("Ini akan dicetak")
frint("karena ini eror")
print("Ini tidak akan dicetak")
# Out:
# Ini akan dicetak
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-14-b5ecf4016bc7> in <cell line: 2>()
#       1 print("Ini akan dicetak")
# ----> 2 frint("karena ini eror")
#       3 print("Ini tidak akan dicetak")
#
# NameError: name 'frint' is not defined

# %%
print("Nama         : David Nazal Farihin ")
print("")
print("NPM          : 2410506005")
print("")
print("Alamat       : Karangsari,Sapuran,Wonosoebo")
print("")
print("Tinggi Badan : 175")
print("")
print("Berat Badan  : 77")
# Out:
# Nama         : David Nazal Farihin
#
# NPM          : 2410506005
#
# Alamat       : Karangsari,Sapuran,Wonosoebo
#
# Tinggi Badan : 175
#
# Berat Badan  : 77

# %%
print("\033[1mUNIVERSITAS TIDAR\033[0m")
print("Universitas Tidar merupakan Perguruan Tinggi Pemerintah atau Perguruan Tinggi Negri yang ditetapkan berdasarkan ")
print("")
print("\033[1mJURUSAN TEKNIK ELEKTRO, MEKATRONIKA DAN INFORMASI\033[0m")
print("Jurusan Teknik Elektro terdiri atas tiga program study, antara lain:")
print("    1. S1 Teknik Elektro \x1B[3m(Bachelor of Electrical Engineering)\x1B[0m")
print("    2. S1 Teknologi Informasi \x1B[3m(Bachelor of Information Technology)\x1B[0m")
print("    3. S1 Teknik Mekatronika \x1B[3m( Banchelor of Mechatronics Enginering)\x1B[0m ")
# Out:
# UNIVERSITAS TIDAR
# Universitas Tidar merupakan Perguruan Tinggi Pemerintah atau Perguruan Tinggi Negri yang ditetapkan berdasarkan
#
# JURUSAN TEKNIK ELEKTRO, MEKATRONIKA DAN INFORMASI
# Jurusan Teknik Elektro terdiri atas tiga program study, antara lain:
#     1. S1 Teknik Elektro (Bachelor of Electrical Engineering)
#     2. S1 Teknologi Informasi (Bachelor of Information Technology)
#     3. S1 Teknik Mekatronika ( Banchelor of Mechatronics Enginering)
